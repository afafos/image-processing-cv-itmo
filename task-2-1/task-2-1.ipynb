# %%
import cv2

# %%
img = cv2.imread("image.jpg")
img.shape
# Out:
# (4912, 7360, 3)

# %%
height, width, channels = img.shape
print("width =", width)
print("height =", height)
# Out:
# width = 7360
# height = 4912

# %%
b, g, r = img[2469, 3652]
print("R =", int(r))
print("G =", int(g))
print("B =", int(b))
# Out:
# R = 126
# G = 62
# B = 88
